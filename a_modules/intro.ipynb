# %% [markdown]
# # Modules
#
# Here you can find sections created specifically for certain modules, containing notebooks very closely connected to lectures. These are:
#
# ```{tableofcontents}
# ```
#
# Make sure to also check below for content throughout the primer related to specific modules.

# %% [markdown]
# ## Year 1
#
# (module-dynep)=
# ### Dynamic Earth and Planets
#
# [<!-- module-dynep badge --><span class="module module-dynep">Dynamic Earth and Planets</span>](module-dynep)
#
# (module-strat1)=
# ### Stratigraphy (Year 1)
#
# [<!-- module-strat1 badge --><span class="module module-strat1">Stratigraphy (Year 1)</span>](module-strat1)
#
# (module-gmat)=
# ### Geomaterials
#
# [<!-- module-gmat badge --><span class="module module-gmat">Geomaterials</span>](module-gmat)
#
# (module-prog)=
# ### Programming for Geoscientists
#
# [<!-- module-progr badge --><span class="module module-progr">Programming for Geoscientists</span>](module-progr)
#
# - {doc}`NumPy arrays <notebooks\coding\NumPy_Arrays.ipynb>`
#
# (module-mfg)=
# ### Mathematics for Geoscientists
#
# [<!-- module-mfg badge --><span class="module module-mfg">Mathematics for Geoscientists</span>](module-mfg)
#
# (module-mm1)=
# ### Mathematics Methods 1
#
# [<!-- module-mm1 badge --><span class="module module-mm1">Maths Methods 1</span>](module-mm1)
#
# - {doc}`Eigenvalues <notebooks\mathematics\moduletags.ipynb>`
# - {doc}`Matrix multiplication <notebooks\mathematics\complex_analysis\mynotebook.ipynb>`
# - {doc}`Matrices (Lecture 4) <notebooks\modules\math_methods_1\Matrices_Linear_Algebra.ipynb>`
#
# (module-cfg)=
# ### Chemistry for Geoscientists
#
# [<!-- module-cfg badge --><span class="module module-cfg">Chemistry for Geoscientists</span>](module-cfg)
#
# (module-lfg)=
# ### Low-Temperature Geochemistry
#
# [<!-- module-lfg badge --><span class="module module-lfg">Low-Temperature Geochemistry</span>](module-lfg)
#
# (module-dte)=
# ### Deforming the Earth
#
# [<!-- module-dte badge --><span class="module module-dte">Deforming the Earth</span>](module-dte)
#
# (module-lodt)=
# ### Life over Deep Time
#
# [<!-- module-lodt badge --><span class="module module-lodt">Life over Deep Time</span>](module-lodt)
#
# (module-gitf)=
# ### Geology in the Field
#
# [<!-- module-gitf badge --><span class="module module-gitf">Geology in the Field</span>](module-gitf)
#
# (module-phyp)=
# ### Physical Processes
#
# [<!-- module-phyp badge --><span class="module module-phyp">Physical Processes</span>](module-phyp)
#
# (module-surp)=
# ### Surface Processes
#
# [<!-- module-surp badge --><span class="module module-surp">Surface Processes</span>](module-surp)
#
# (module-vip)=
# ### Volcanism and Internal Processes
#
# [<!-- module-vip badge --><span class="module module-vip">Volcanism and Internal Processes</span>](module-vip)
#
# (module-mm2)=
# ### Mathematics Methods 2
#
# [<!-- module-mm2 badge --><span class="module module-mm2">Maths Methods 2</span>](module-mm2)
#
# - {doc}`Fluid Dynamics <notebooks\mathematics\moduletags.ipynb>`
# - {doc}`Timestepping an ODE <notebooks\mathematics\moduletags.ipynb>`
#
# (module-exstat)=
# ### Excel and Statistics
#
# [<!-- module-exstat badge --><span class="module module-exstat">Excel and Statistics</span>](module-exstat)
#
# (module-graph)=
# ### Graphics
#
# [<!-- module-graph badge --><span class="module module-graph">Graphics</span>](module-graph)
#
# (module-fieldsk)=
# ### Field Skills
#
# [<!-- module-fieldsk badge --><span class="module module-fieldsk">Field Skills</span>](module-fieldsk)
#
#
# ## Year 2
#
# (module-ssg)=
# ### Solar System Geoscience
#
# [<!-- module-ssg badge --><span class="module module-ssg">Solar System Geoscience</span>](module-ssg)
#
# (module-htg)=
# ### High-Temperature Geochemistry
#
# [<!-- module-htg badge --><span class="module module-htg">High-Temperature Geochemistry</span>](module-htg)
#
# (module-maps)=
# ### Maps and Structures
#
# [<!-- module-maps badge --><span class="module module-maps">Maps and Structures</span>](module-maps)
#
# (module-puregp)=
# ### Pure Geophysics
#
# [<!-- module-puregp badge --><span class="module module-puregp">Pure Geophysics</span>](module-puregp)
#
# (module-appgp)=
# ### Applied Geophysics
#
# [<!-- module-appgp badge --><span class="module module-appgp">Applied Geophysics</span>](module-appgp)
#
# (module-rsitf)=
# ### Rocks and Structures in the Field
#
# [<!-- module-rsitf badge --><span class="module module-rsitf">Rocks and Structures in the Field</span>](module-rsitf)
#
# (module-fieldgp)=
# ### Field Geophysics
#
# [<!-- module-fieldgp badge --><span class="module module-fieldgp">Field Geophysics</span>](module-fieldgp)
#
# - {doc}`1D resistivity forward modelling <notebooks\geosciences\1D_Resistivity_Forward_Modelling.ipynb>`
#
# (module-igg)=
# ### Igneous Geology
#
# [<!-- module-igg badge --><span class="module module-igg">Igneous Geology</span>](module-igg)
#
# (module-metg)=
# ### Metamorphic Geology
#
# [<!-- module-metg badge --><span class="module module-metg">Metamorphic Geology</span>](module-metg)
#
# (module-sedi)=
# ### Sediments
#
# [<!-- module-sedi badge --><span class="module module-sedi">Sediments</span>](module-sedi)
#
# (module-strat2)=
# ### Stratigraphy (Year 2)
#
# [<!-- module-strat2 badge --><span class="module module-strat2">Stratigraphy (Year 2)</span>](module-strat2)
#
# (module-rsep)=
# ### Remote Sensing Earth and Planets
#
# [<!-- module-rsep badge --><span class="module module-rsep">Remote Sensing Earth and Planets</span>](module-rsep)
#
# - {doc}`Moving average filter <notebooks\geosciences\remote_sensing\Image_Filtering.ipynb>`
# - {doc}`Sharpening filters <notebooks\geosciences\remote_sensing\Image_Filtering.ipynb>`
# - {doc}`Edge detection (gradient operators) <notebooks\geosciences\remote_sensing\Image_Filtering.ipynb>`
# - {doc}`Point operations <notebooks\geosciences\remote_sensing\Image_Point_Operations.ipynb>`
#
# (module-mse1)=
# ### Mathematics for Scientists and Engineers 1
#
# [<!-- module-mse1 badge --><span class="module module-mse1">Mathematics for Scientists and Engineers 1</span>](module-mse1)
#
# (module-mse2)=
# ### Mathematics for Scientists and Engineers 2
#
# [<!-- module-mse2 badge --><span class="module module-mse2">Mathematics for Scientists and Engineers 2</span>](module-mse2)
#
# - {doc}`Laplace's \\( u_{xx} + u_{yy} = 0 \\) <notebooks\mathematics\moduletags.ipynb>`
#
# (module-mech)=
# ### Mechanics
#
# [<!-- module-mech badge --><span class="module module-mech">Mechanics</span>](module-mech)
#
# (module-wave)=
# ### Waves
#
# [<!-- module-wave badge --><span class="module module-wave">Waves</span>](module-wave)
#
# (module-egacr)=
# ### Environmental Geochemistry and Climate Report
#
# [<!-- module-egacr badge --><span class="module module-egacr">Environmental Geochemistry and Climate Report</span>](module-egacr)
#
# (module-pala)=
# ### Palaeontology
#
# [<!-- module-pala badge --><span class="module module-pala">Palaeontology</span>](module-pala)
#
# (module-om)=
# ### Optical Mineralogy
#
# [<!-- module-om badge --><span class="module module-om">Optical Mineralogy</span>](module-om)
#
# (module-seis)=
# ### Seismology
#
# [<!-- module-seis badge --><span class="module module-seis">Seismology</span>](module-seis)
#
# - {doc}`Downloading earthquake data <notebooks\geosciences\Seismology.ipynb>`
#
# (module-nm)=
# ### Numerical Methods
#
# [<!-- module-nm badge --><span class="module module-nm">Numerical Methods</span>](module-nm)
#
# - {doc}`Timestepping an ODE <notebooks\mathematics\moduletags.ipynb>`
#
#
# ## Year 3/4
#
# (module-indpmap)=
# ### Independent Project - Mapping
#
# [<!-- module-indpmap badge --><span class="module module-indpmap">Independent Project - Mapping</span>](module-indpmap)
#
# (module-indpgp)=
# ### Independent Project - Geophysics
#
# [<!-- module-indpgp badge --><span class="module module-indpgp">Independent Project - Geophysics</span>](module-indpgp)
#
# module-indpes)=
# ### Independent Project - Earth Science
#
# [<!-- module-indpes badge --><span class="module module-indpes">Independent Project - Earth Science</span>](module-indpes)
#
# (module-indpls)=
# ### Independent Project - Landing Site
#
# [<!-- module-indpls badge --><span class="module module-indpls">Independent Project - Landing Site</span>](module-indpls)
#
# (module-ct)=
# ### Continental Tectonics
#
# [<!-- module-ct badge --><span class="module module-ct">Continental Tectonics</span>](module-ct)
#
# (module-clim)=
# ### Climate
#
# [<!-- module-clim badge --><span class="module module-clim">Climate</span>](module-clim)
#
# (module-nssi)=
# ### Near Surface Seismic Imaging
#
# [<!-- module-nssi badge --><span class="module module-nssi">Near Surface Seismic Imaging</span>](module-nssi)
#
# (module-ars)=
# ### Advanced Remote Sensing
#
# [<!-- module-ars badge --><span class="module module-ars">Advanced Remote Sensing</span>](module-ars)
#
# - {doc}`Point operations <notebooks\geosciences\remote_sensing\Image_Point_Operations.ipynb>`
# - {doc}`Cut-off clipping <notebooks\geosciences\remote_sensing\Image_Point_Operations.ipynb>`
# - {doc}`Contrast enhancement <notebooks\geosciences\remote_sensing\Image_Point_Operations.ipynb>`
# - {doc}`Balance contrast enhancement technique (BCET)$^2$ <notebooks\geosciences\remote_sensing\Image_Point_Operations.ipynb>`
#
# (module-iafg)=
# ### Integrated Advanced Field Geology
#
# [<!-- module-iafg badge --><span class="module module-iafg">Integrated Advanced Field Geology</span>](module-iafg)
#
# (module-ored)=
# ### Ore Deposits
#
# [<!-- module-ored badge --><span class="module module-ored">Ore Deposits</span>](module-ored)
#
# (module-mem)=
# ### Mining Environmental Management
#
# [<!-- module-mem badge --><span class="module module-mem">Mining Environmental Management</span>](module-mem)
#
# (module-envsemi)=
# ### Environmental Seminar
#
# [<!-- module-envsemi badge --><span class="module module-envsemi">Environmental Seminar</span>](module-envsemi)
#
# (module-astbio)=
# ### Astrobiology
#
# [<!-- module-astbio badge --><span class="module module-astbio">Astrobiology</span>](module-astbio)
#
# (module-esys)=
# ### Earth Systems
#
# [<!-- module-esys badge --><span class="module module-esys">Earth Systems</span>](module-esys)
#
# (module-gace)=
# ### Geological and Coastal Engineering
#
# [<!-- module-gace badge --><span class="module module-gace">Geological and Coastal Engineering</span>](module-gace)
#
# (module-advprog)=
# ### Advanced Programming
#
# [<!-- module-advprog badge --><span class="module module-advprog">Advanced Programming</span>](module-astbio)
#
# (module-gmod)=
# ### Gravity, Magnetism, and Orbital Dynamics
#
# [<!-- module-gmod badge --><span class="module module-gmod">Gravity, Magnetism, and Orbital Dynamics</span>](module-gmod)
#
# - {doc}`Keplerian orbits <notebooks\geosciences\Keplerian_Orbits.ipynb>`
#
# (module-psdp)=
# ### Practical Seismic Data Processing
#
# [<!-- module-psdp badge --><span class="module module-psdp">Practical Seismic Data Processing</span>](module-psdp)
#
# (module-plasur)=
# ### Planetary Surfaces
#
# [<!-- module-plasur badge --><span class="module module-plasur">Planetary Surfaces</span>](module-plasur)
#
# (module-toto)=
# ### Tectonics of the Ocean
#
# [<!-- module-toto badge --><span class="module module-toto">Tectonics of the Ocean</span>](module-toto)
#
# (module-aag)=
# ### Advanced Applied Geophysics
#
# [<!-- module-aag badge --><span class="module module-aag">Advanced Applied Geophysics</span>](module-aag)
#
# (module-hff)=
# ### Hydrogeology and Fluid Flow
#
# [<!-- module-hff badge --><span class="module module-hff">Hydrogeology and Fluid Flow</span>](module-hff)
#
# (module-gfdocean)=
# ### Geophysical Fluid Dynamics of the Oceans
#
# [<!-- module-gfdocean badge --><span class="module module-astbio">Geophysical Fluid Dynamics of the Oceans</span>](module-gfdocean)
#
# (module-mgae)=
# ### Mining Geology and Engineering
#
# [<!-- module-mgae badge --><span class="module module-mgae">Mining Geology and Engineering</span>](module-mgae)
#
# (module-cps)=
# ### Comparative Planetary Science
#
# [<!-- module-cps badge --><span class="module module-cps">Comparative Planetary Science</span>](module-cps)
#
# (module-dsml)=
# ### Data Science and Machine Learning for Geoscientists
#
# [<!-- module-dsml badge --><span class="module module-dsml">Data Science and Machine Learning for Geoscientists</span>](module-dsml)
#
# (module-ghaz)=
# ### Geohazards
#
# [<!-- module-ghaz badge --><span class="module module-ghaz">Geohazards</span>](module-ghaz)
#
# (module-ageomo)=
# ### Applied Geomorphology
#
# [<!-- module-ageomo badge --><span class="module module-ageomo">Applied Geomorphology</span>](module-ageomo)
#
# (module-minep)=
# ### Mineral Processing
#
# [<!-- module-minep badge --><span class="module module-minep">Mineral Processing</span>](module-minep)
#
# (module-aes)=
# ### Advanced Exploration Seismology
#
# [<!-- module-aes badge --><span class="module module-aes">Advanced Exploration Seismology</span>](module-aes)
#
# (module-fgamb)=
# ### Field Geology of an Active Mountain Belt
#
# [<!-- module-fgamb badge --><span class="module module-fgamb">Field Geology of an Active Mountain Belt</span>](module-fgamb)
#
# (module-ginv)=
# ### Geophysical Inversion
#
# [<!-- module-ginv badge --><span class="module module-ginv">Geophysical Inversion</span>](module-ginv)
#
# - {doc}`Eigenvalues <notebooks\mathematics\moduletags.ipynb>`
#
# (module-gdyn)=
# ### Geodynamics
#
# [<!-- module-gdyn badge --><span class="module module-gdyn">Geodynamics</span>](module-gdyn)
#
# - {doc}`1D heat conduction (layered medium) <notebooks\geosciences\1D_Heat_Conduction.ipynb>`
# - {doc}`1D pipe flow <notebooks\geosciences\Lecture5_1D_Pipe_Flow.ipynb>`
#
# (module-cac)=
# ### Collisions and Craters
#
# [<!-- module-cac badge --><span class="module module-cac">Collisions and Craters</span>](module-cac)
#
# (module-ampap)=
# ### Arc Magmatic Processes and Products
#
# [<!-- module-ampap badge --><span class="module module-ampap">Arc Magmatic Processes and Products</span>](module-ampap)
#
# (module-grt)=
# ### Geological Reactive transport
#
# [<!-- module-grt badge --><span class="module module-grt">Geological Reactive transport</span>](module-grt)
#
# (module-palabio)=
# ### Palaeobiology
#
# [<!-- module-palabio badge --><span class="module module-palabio">Palaeobiology</span>](module-palabio)
#
# (module-palaocean)=
# ### Palaeoceanography
#
# [<!-- module-palaocean badge --><span class="module module-palaocean">Palaeoceanography</span>](module-palaocean)
#
# (module-gagp)=
# ### Geophysical Synthesis Group Project
#
# [<!-- module-gagp badge --><span class="module module-gagp">Geophysical Synthesis Group Project</span>](module-gagp)
#
# (module-plaphy)=
# ### Planetary Physics
#
# [<!-- module-plaphy badge --><span class="module module-plaphy">Planetary Physics</span>](module-plaphy)
#
# (module-plachem)=
# ### Planetary Chemistry
#
# [<!-- module-plachem badge --><span class="module module-plachem">Planetary Chemistry</span>](module-plachem)
#
# (module-meteo)=
# ### Meteorites
#
# [<!-- module-meteo badge --><span class="module module-meteo">Meteorites</span>](module-meteo)
