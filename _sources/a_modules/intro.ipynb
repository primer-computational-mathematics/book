# %% [markdown]
# # Modules
#
# Here you can find sections created specifically for certain modules, containing notebooks very closely connected to lectures. These are:
#
# ```{tableofcontents}
# ```
#
# Make sure to also check below for content throughout the primer related to specific modules.

# %% [markdown]
# ## Year 1
# (module-dynep)=
# ### Dynamic Earth and Planets
#
# [<!-- module-dynep badge --><span class="module module-dynep">Dynamic Earth and Planets</span>](module-dynep)
#
# - {doc}`Milankovitch cycles </d_geosciences/Milankovitch_cycles>`
# - {doc}`Seafloor ages </d_geosciences/Seafloor_ages>`
#
# (module-strat1)=
# ### Stratigraphy (Year 1)
#
# [<!-- module-strat1 badge --><span class="module module-strat1">Stratigraphy (Year 1)</span>](module-strat1)
#
# - {doc}`Milankovitch cycles </d_geosciences/Milankovitch_cycles>`
#
# (module-prog)=
# ### Programming for Geoscientists
#
# [<!-- module-prog badge --><span class="module module-prog">Programming for Geoscientists</span>](module-prog)
#
# - {doc}`Assert </b_coding/Intro to Python/18_Assert>`
# - {doc}`Creating custom functions </b_coding/Intro to Python/11_Functions>`
# - {doc}`Creating date-time stamps </b_coding/Pandas/5_time_stamps>`
# - {doc}`Dictionaries </b_coding/Intro to Python/14_Dictionaries>`
# - {doc}`File handling </b_coding/Intro to Python/13_File_handling>`
# - {doc}`Filtering, selecting and assigning </b_coding/Pandas/2_filter_select_assign>`
# - {doc}`Flow control statements </b_coding/Intro to Python/15_Flow_control_statements>`
# - {doc}`For loops </b_coding/Intro to Python/6_For_loops>`
# - {doc}`Handling errors </b_coding/Intro to Python/9_Handling_errors>`
# - {doc}`If statement </b_coding/Intro to Python/3_If_statement>`
# - {doc}`Importing in Python </b_coding/Intro to Python/10_Importing>`
# - {doc}`Introduction </b_coding/Pandas/1_basics>`
# - {doc}`Lambdas </b_coding/Intro to Python/20_Lambdas>`
# - {doc}`List comprehensions </b_coding/Intro to Python/7_List_comprehensions>`
# - {doc}`Lists </b_coding/Intro to Python/5_Lists>`
# - {doc}`Merging, combining, grouping and sorting </b_coding/Pandas/3_merge_combine_group_sort>`
# - {doc}`Nested lists </b_coding/Intro to Python/8_Nested_lists>`
# - {doc}`NumPy arrays </b_coding/NumPy_Arrays>`
# - {doc}`Plotting </b_coding/Pandas/6_plotting>`
# - {doc}`Plotting data with Matplotlib </b_coding/Intro to Python/17_Matplotlib>`
# - {doc}`Printing and formatting statements </b_coding/Intro to Python/1_Printing_and_formatting_statements>`
# - {doc}`Python classes </b_coding/Intro to Python/19_Classes>`
# - {doc}`Sets </b_coding/Intro to Python/16_Sets>`
# - {doc}`Summary statistics </b_coding/Pandas/4_summary_statistics>`
# - {doc}`Tuples </b_coding/Intro to Python/12_Tuples>`
# - {doc}`Variables </b_coding/Intro to Python/2_Variables>`
# - {doc}`While loops </b_coding/Intro to Python/4_While_loops>`
#
# (module-mfg)=
# ### Mathematics for Geoscientists
#
# [<!-- module-mfg badge --><span class="module module-mfg">Mathematics for Geoscientists</span>](module-mfg)
#
# - {doc}`Composition and Inverse Functions </c_mathematics/sets_and_functions/6_composition_and_inverse>`
# - {doc}`Elementary functions 1 </c_mathematics/sets_and_functions/4_elementary_functions_1>`
# - {doc}`Elementary functions 2 </c_mathematics/sets_and_functions/5_elementary_functions_2>`
# - {doc}`Functions </c_mathematics/sets_and_functions/3_functions>`
# - {doc}`Logic and proof </c_mathematics/sets_and_functions/1_logic>`
# - {doc}`Sets </c_mathematics/sets_and_functions/2_sets>`
#
# (module-mm1)=
# ### Mathematics Methods 1
#
# [<!-- module-mm1 badge --><span class="module module-mm1">Mathematics Methods 1</span>](module-mm1)
#
# - {doc}`Basic definitions and operations </c_mathematics/linear_algebra/1_Basic_definitions_and_operations>`
# - {doc}`Coordinate systems </a_modules/math_methods_1/1_Coordinate_Systems>`
# - {doc}`Eigenvalues </a_modules/math_methods_1/6_Eigenvalues>`
# - {doc}`Eigenvalues and eigenvectors </c_mathematics/linear_algebra/4_Eigenvalues_and_eigenvectors>`
# - {doc}`First-order ODEs </c_mathematics/differential_equations/3_first-order_odes>`
# - {doc}`Introduction to differential equations </c_mathematics/differential_equations/1_de_introduction>`
# - {doc}`Linear regression </c_mathematics/statistics/Linear_Regression>`
# - {doc}`Matrices </a_modules/math_methods_1/5_Matrices>`
# - {doc}`Modelling </a_modules/math_methods_1/9_Modelling>`
# - {doc}`Multivariable calculus </a_modules/math_methods_1/3_Multivariable_Calculus>`
# - {doc}`ODEs </a_modules/math_methods_1/8_ODEs>`
# - {doc}`Series </a_modules/math_methods_1/7_Series>`
# - {doc}`Systems of linear equations </c_mathematics/linear_algebra/2_Linear_Systems>`
# - {doc}`Taylor series </c_mathematics/series_and_sequences/Taylor_series>`
# - {doc}`Vector calculus </a_modules/math_methods_1/4_Vector_Calculus>`
# - {doc}`Vectors </a_modules/math_methods_1/2_Vectors>`
#
# (module-cfg)=
# ### Chemistry for Geoscientists
#
# [<!-- module-cfg badge --><span class="module module-cfg">Chemistry for Geoscientists</span>](module-cfg)
#
# - {doc}`Arrhenius Equation </d_geosciences/Low-Temperature Geochemistry/Arrhenius_Equation>`
# - {doc}`Rate Law </d_geosciences/Low-Temperature Geochemistry/Rate_Law>`
#
# (module-ltg)=
# ### Low-Temperature Geochemistry
#
# [<!-- module-ltg badge --><span class="module module-ltg">Low-Temperature Geochemistry</span>](module-ltg)
#
# - {doc}`Arrhenius Equation </d_geosciences/Low-Temperature Geochemistry/Arrhenius_Equation>`
# - {doc}`CO2-H2O System </d_geosciences/Low-Temperature Geochemistry/CO2_H2O_System>`
# - {doc}`Defining activity coefficients </d_geosciences/Low-Temperature Geochemistry/Defining_Activity_Coefficients>`
# - {doc}`Hess' law </d_geosciences/Low-Temperature Geochemistry/Hess_Law>`
# - {doc}`Rate Law </d_geosciences/Low-Temperature Geochemistry/Rate_Law>`
# - {doc}`Reaction Quotients </d_geosciences/Low-Temperature Geochemistry/Reaction_Quotients>`
# - {doc}`Stability Diagram </d_geosciences/Low-Temperature Geochemistry/Stability_Diagram>`
#
# (module-phyp)=
# ### Physical Processes
#
# [<!-- module-phyp badge --><span class="module module-phyp">Physical Processes</span>](module-phyp)
#
# - {doc}`Dimensional Analysis </d_geosciences/Physical Processes/Dimensional_Analysis>`
# - {doc}`Fluids & the Bernoulli effect </d_geosciences/Physical Processes/Fluids_&_the_Bernoulli_effect>`
# - {doc}`Heat </d_geosciences/Physical Processes/Heat>`
# - {doc}`Reynolds number </d_geosciences/Physical Processes/Reynolds_number>`
#
# (module-mm2)=
# ### Mathematics Methods 2
#
# [<!-- module-mm2 badge --><span class="module module-mm2">Mathematics Methods 2</span>](module-mm2)
#
# - {doc}`Complex Numbers </a_modules/mathematical_methods_2/1_complex_numbers>`
# - {doc}`Complex algebra </c_mathematics/complex_analysis/1_introduction>`
# - {doc}`Complex plane </c_mathematics/complex_analysis/2_complex_plane>`
# - {doc}`First-order ODEs </c_mathematics/differential_equations/3_first-order_odes>`
# - {doc}`Fourier series </c_mathematics/series_and_sequences/Fourier_series>`
# - {doc}`Fourier series </d_geosciences/Waves/Fourier_Series>`
# - {doc}`Higher order Linear ODEs </c_mathematics/differential_equations/4_higher_ord_lin_odes>`
# - {doc}`Introduction </c_mathematics/complex_analysis/1_introduction>`
# - {doc}`Introduction to differential equations </c_mathematics/differential_equations/1_de_introduction>`
# - {doc}`Linear ODEs </c_mathematics/differential_equations/2_linear_des>`
# - {doc}`Series ODE </c_mathematics/differential_equations/5_ode_series>`
# - {doc}`Taylor series </c_mathematics/series_and_sequences/Taylor_series>`
#
# (module-exstat)=
# ### Excel and Statistics
#
# [<!-- module-exstat badge --><span class="module module-exstat">Excel and Statistics</span>](module-exstat)
#
# - {doc}`Introduction to statistics for Geoscientists </c_mathematics/statistics/Statistics_for_Geoscientists>`
# - {doc}`Linear regression </c_mathematics/statistics/Linear_Regression>`
#
# ## Year 2
# (module-htg)=
# ### High-Temperature Geochemistry
#
# [<!-- module-htg badge --><span class="module module-htg">High-Temperature Geochemistry</span>](module-htg)
#
# - {doc}`Milankovitch cycles </d_geosciences/Milankovitch_cycles>`
#
# (module-puregp)=
# ### Pure Geophysics
#
# [<!-- module-puregp badge --><span class="module module-puregp">Pure Geophysics</span>](module-puregp)
#
# - {doc}`Euler Pole </a_modules/continental_tectonics/Euler_Pole>`
# - {doc}`Plotting Earthquake Focus </d_geosciences/3D_Earthquake_Focus_Plot>`
#
# (module-appgp)=
# ### Applied Geophysics
#
# [<!-- module-appgp badge --><span class="module module-appgp">Applied Geophysics</span>](module-appgp)
#
# - {doc}`Gravity corrections </d_geosciences/Pure and Applied Geophysics/Gravity correction>`
# - {doc}`Magnetic surveys </d_geosciences/Pure and Applied Geophysics/Magnetic surveys>`
#
# (module-fieldgp)=
# ### Field Geophysics
#
# [<!-- module-fieldgp badge --><span class="module module-fieldgp">Field Geophysics</span>](module-fieldgp)
#
# - {doc}`1D resistivity forward modelling </d_geosciences/1D_Resistivity_Forward_Modelling>`
# - {doc}`Gravity corrections </d_geosciences/Pure and Applied Geophysics/Gravity correction>`
# - {doc}`Magnetic surveys </d_geosciences/Pure and Applied Geophysics/Magnetic surveys>`
#
# (module-rsep)=
# ### Remote Sensing Earth and Planets
#
# [<!-- module-rsep badge --><span class="module module-rsep">Remote Sensing Earth and Planets</span>](module-rsep)
#
# - {doc}`Camera calibration </e_extra/Camera_Calibration>`
# - {doc}`Cartopy (maps) </e_extra/Cartography_Cartopy>`
# - {doc}`Image point operations </d_geosciences/remote_sensing/Image_Point_Operations>`
# - {doc}`Reading Maps </d_geosciences/Longitude_Latitude_Degree_Convertion>`
#
# (module-mse1)=
# ### Mathematics for Scientists and Engineers 1
#
# [<!-- module-mse1 badge --><span class="module module-mse1">Mathematics for Scientists and Engineers 1</span>](module-mse1)
#
# - {doc}`Fourier series </d_geosciences/Waves/Fourier_Series>`
# - {doc}`Fourier transforms </c_mathematics/series_and_sequences/Fourier_transforms>`
# - {doc}`Vector calculus </c_mathematics/calculus/Vector_calculus>`
#
# (module-mse2)=
# ### Mathematics for Scientists and Engineers 2
#
# [<!-- module-mse2 badge --><span class="module module-mse2">Mathematics for Scientists and Engineers 2</span>](module-mse2)
#
# - {doc}`Canonical form of second-order linear PDEs </c_mathematics/differential_equations/8_pde_second_order>`
# - {doc}`First-order linear PDEs </c_mathematics/differential_equations/7_pde_first_order>`
# - {doc}`Heat (diffusion) equation </c_mathematics/differential_equations/10_heat_eq>`
# - {doc}`Introduction to differential equations </c_mathematics/differential_equations/1_de_introduction>`
# - {doc}`Introductory definitions and concepts </c_mathematics/differential_equations/6_pde_basicdefinitions>`
# - {doc}`Linear PDEs </c_mathematics/differential_equations/2_linear_des>`
# - {doc}`Poisson's and Laplace's equation </c_mathematics/differential_equations/9_poisson_laplace_eq>`
# - {doc}`Self-similar solutions </c_mathematics/differential_equations/13_similarity_solutions>`
# - {doc}`Solving PDEs with fourier methods </c_mathematics/differential_equations/11_pde_fourier>`
# - {doc}`Tensor indices </c_mathematics/mathematical_notation/Tensors_Review>`
# - {doc}`Wave equation </c_mathematics/differential_equations/12_wave_eq>`
#
# (module-mech)=
# ### Mechanics
#
# [<!-- module-mech badge --><span class="module module-mech">Mechanics</span>](module-mech)
#
# - {doc}`Gravity </a_modules/mechanics/5_Gravity>`
# - {doc}`Motion in 1D </a_modules/mechanics/1_Motion_in_1D>`
# - {doc}`Motion in 2D </a_modules/mechanics/2_Motion_in_2D>`
# - {doc}`Review of tensors </c_mathematics/mathematical_notation/Tensors_Review>`
# - {doc}`Rotational Motion </a_modules/mechanics/4_Rotational_Motion>`
# - {doc}`Work and Energy </a_modules/mechanics/3_Work_and_Energy>`
#
# (module-wave)=
# ### Waves
#
# [<!-- module-wave badge --><span class="module module-wave">Waves</span>](module-wave)
#
# - {doc}`Attenuation </d_geosciences/Waves/Attenuation>`
# - {doc}`Fourier series </c_mathematics/series_and_sequences/Fourier_series>`
# - {doc}`Fourier series </d_geosciences/Waves/Fourier_Series>`
# - {doc}`Impedance, Transmission and Reflection </d_geosciences/Waves/Transmission_and_Reflection>`
# - {doc}`Introduction to waves </d_geosciences/Waves/Introduction_To_Waves>`
# - {doc}`Superposition of Waves, Reflection and Refraction </d_geosciences/Waves/Refraction>`
#
# (module-seis)=
# ### Seismology
#
# [<!-- module-seis badge --><span class="module module-seis">Seismology</span>](module-seis)
#
# - {doc}`Downloading earthquake data </d_geosciences/Downloading_earthquake_data>`
# - {doc}`Plotting Earthquake Focus </d_geosciences/3D_Earthquake_Focus_Plot>`
# - {doc}`Review of tensors </c_mathematics/mathematical_notation/Tensors_Review>`
#
# (module-nm)=
# ### Numerical Methods
#
# [<!-- module-nm badge --><span class="module module-nm">Numerical Methods</span>](module-nm)
#
# - {doc}`Big O notation </c_mathematics/mathematical_notation/Big_O_notation>`
# - {doc}`Forward Euler scheme </c_mathematics/numerical_methods/3_Timestepping_an_ODE>`
# - {doc}`Gauss-Jordan elimination </c_mathematics/linear_algebra/2_Linear_Systems>`
# - {doc}`Gaussian elimination </c_mathematics/linear_algebra/2_Linear_Systems>`
# - {doc}`Gaussian elimination </c_mathematics/numerical_methods/12_Gaussian_elimination>`
# - {doc}`Heun's method </c_mathematics/numerical_methods/4_Heuns_method>`
# - {doc}`Ill-conditioning and roundoff errors </c_mathematics/numerical_methods/14_ill_conditioning_errors>`
# - {doc}`Interpolation and curve fitting </c_mathematics/numerical_methods/1_Interpolation_curve_fitting>`
# - {doc}`Iterative methods to solve a matrix </c_mathematics/numerical_methods/15_iterative_methods_to_solve_matrix>`
# - {doc}`LU decomposition </c_mathematics/numerical_methods/13_LU_decomposition>`
# - {doc}`Linear Algebra in Python </c_mathematics/linear_algebra/5_Linear_Algebra_in_Python>`
# - {doc}`Linear algebra introduction </c_mathematics/numerical_methods/11_linear_algebra_intro>`
# - {doc}`Linear regression </c_mathematics/statistics/Linear_Regression>`
# - {doc}`Numerical differentiation </c_mathematics/numerical_methods/2_Numerical_differentiation>`
# - {doc}`Numerical integration </c_mathematics/numerical_methods/9_Numerical_integration>`
# - {doc}`Roots of equations </c_mathematics/numerical_methods/10_Roots_of_equations>`
# - {doc}`Systems of linear equations </c_mathematics/linear_algebra/2_Linear_Systems>`
# - {doc}`Taylor series </c_mathematics/series_and_sequences/Taylor_series>`
#
# ## Year 3/4
# (module-indpgp)=
# ### Independent Project - Geophysics
#
# [<!-- module-indpgp badge --><span class="module module-indpgp">Independent Project - Geophysics</span>](module-indpgp)
#
# - {doc}`Downloading earthquake data </d_geosciences/Downloading_earthquake_data>`
#
# (module-ct)=
# ### Continental Tectonics
#
# [<!-- module-ct badge --><span class="module module-ct">Continental Tectonics</span>](module-ct)
#
# - {doc}`Euler Pole </a_modules/continental_tectonics/Euler_Pole>`
# - {doc}`Isostasy </a_modules/continental_tectonics/Isostasy>`
# - {doc}`Lithospheric Strength </a_modules/continental_tectonics/Lithospheric_Strength>`
# - {doc}`Ridge Push and Slab Pull </a_modules/continental_tectonics/Ridge_Push_and_Slab_Pull>`
#
# (module-clim)=
# ### Climate
#
# [<!-- module-clim badge --><span class="module module-clim">Climate</span>](module-clim)
#
# - {doc}`Climate model </d_geosciences/Climate_Model>`
# - {doc}`Milankovitch cycles </d_geosciences/Milankovitch_cycles>`
#
# (module-ars)=
# ### Advanced Remote Sensing
#
# [<!-- module-ars badge --><span class="module module-ars">Advanced Remote Sensing</span>](module-ars)
#
# - {doc}`Cartopy (maps) </e_extra/Cartography_Cartopy>`
# - {doc}`Google Earth Engine foundations </e_extra/Google_Earth_Engine_Foundations>`
# - {doc}`Google Earth Engine getting started </e_extra/Google_Earth_Engine_Getting_Started_>`
# - {doc}`Image filtering </d_geosciences/remote_sensing/Image_Filtering>`
# - {doc}`Image point operations </d_geosciences/remote_sensing/Image_Point_Operations>`
# - {doc}`Image transformations and orthorectification </d_geosciences/remote_sensing/Image_Transformations_and_Orthorectification>`
#
# (module-gmod)=
# ### Gravity, Magnetism, and Orbital Dynamics
#
# [<!-- module-gmod badge --><span class="module module-gmod">Gravity, Magnetism, and Orbital Dynamics</span>](module-gmod)
#
# - {doc}`Electricity and magnetism </d_geosciences/Electromagnetism/1_electricity_magnetism>`
# - {doc}`Gauss's law </d_geosciences/Electromagnetism/2_maxwell_eqs>`
# - {doc}`Keplerian orbits </d_geosciences/Keplerian_Orbits>`
# - {doc}`Milankovitch cycles </d_geosciences/Milankovitch_cycles>`
# - {doc}`The four-field formalism </d_geosciences/Electromagnetism/3_four_field>`
#
# (module-psdp)=
# ### Practical Seismic Data Processing
#
# [<!-- module-psdp badge --><span class="module module-psdp">Practical Seismic Data Processing</span>](module-psdp)
#
# - {doc}`Common Mid-point Gather </a_modules/seismology/CMP_Common_Mid_Point_Gather>`
# - {doc}`Ghosting </a_modules/seismology/Ghosting>`
# - {doc}`Spatial Aliasing </a_modules/seismology/Spatial_aliasing>`
# - {doc}`Temporal Aliasing </a_modules/seismology/Temporal_aliasing>`
#
# (module-toto)=
# ### Tectonics of the Ocean
#
# [<!-- module-toto badge --><span class="module module-toto">Tectonics of the Ocean</span>](module-toto)
#
# - {doc}`Heat Flow </a_modules/tectonics_of_the_ocean/Plate_Models>`
# - {doc}`Reading Maps </d_geosciences/Longitude_Latitude_Degree_Convertion>`
# - {doc}`Seafloor ages </d_geosciences/Seafloor_ages>`
#
# (module-gfdocean)=
# ### Geophysical Fluid Dynamics of the Oceans
#
# [<!-- module-gfdocean badge --><span class="module module-gfdocean">Geophysical Fluid Dynamics of the Oceans</span>](module-gfdocean)
#
# - {doc}`Stream functions and stream lines </d_geosciences/Geophysical Fluid Dynamics/Stream lines>`
# - {doc}`The mixed layer </d_geosciences/Geophysical Fluid Dynamics/Mixed layer>`
# - {doc}`Tides </d_geosciences/Tides>`
# - {doc}`Wave dispersion </d_geosciences/Wave_dispersion>`
#
# (module-dsml)=
# ### Data Science and Machine Learning for Geoscientists
#
# [<!-- module-dsml badge --><span class="module module-dsml">Data Science and Machine Learning for Geoscientists</span>](module-dsml)
#
# - {doc}`Assert </b_coding/Intro to Python/18_Assert>`
# - {doc}`Chapter 0 -- Introduction </e_extra/pytorch_image_filtering_ml/Chapter 0 -- Introduction>`
# - {doc}`Chapter 1 -- Neural Network </e_extra/pytorch_image_filtering_ml/Chapter 1 -- Neural Network>`
# - {doc}`Chapter 10 -- General Back Propagation </e_extra/pytorch_image_filtering_ml/Chapter 10 -- General Back Propagation>`
# - {doc}`Chapter 11 -- Underfitting and Overfitting </e_extra/pytorch_image_filtering_ml/Chapter 11 -- Underfitting and Overfitting>`
# - {doc}`Chapter 12 -- Early-stopping, Dropout & Mini-batch </e_extra/pytorch_image_filtering_ml/Chapter 12 -- Early-stopping, Dropout & Mini-batch>`
# - {doc}`Chapter 13 -- Vanishing Gradient 1 </e_extra/pytorch_image_filtering_ml/Chapter 13 -- Vanishing Gradient 1>`
# - {doc}`Chapter 14 -- Vanishing Gradient 2 </e_extra/pytorch_image_filtering_ml/Chapter 14 -- Vanishing Gradient 2>`
# - {doc}`Chapter 15 -- Regularisation </e_extra/pytorch_image_filtering_ml/Chapter 15 -- Regularisation>`
# - {doc}`Chapter 16 -- Other Activation Functions </e_extra/pytorch_image_filtering_ml/Chapter 16 -- Other Activation Functions>`
# - {doc}`Chapter 17 -- Local Minima Trap </e_extra/pytorch_image_filtering_ml/Chapter 17 -- Local Minima Trap>`
# - {doc}`Chapter 18 -- Softmax </e_extra/pytorch_image_filtering_ml/Chapter 18 -- Softmax>`
# - {doc}`Chapter 19 -- Hyper-Parameters </e_extra/pytorch_image_filtering_ml/Chapter 19 -- Hyper-Parameters>`
# - {doc}`Chapter 2 -- Maximum Likelihood </e_extra/pytorch_image_filtering_ml/Chapter 2 -- Maximum Likelihood>`
# - {doc}`Chapter 20 -- Coding Example </e_extra/pytorch_image_filtering_ml/Chapter 20 -- Coding Example>`
# - {doc}`Chapter 3 -- Cross Entropy </e_extra/pytorch_image_filtering_ml/Chapter 3 -- Cross Entropy>`
# - {doc}`Chapter 4 -- Cost Function </e_extra/pytorch_image_filtering_ml/Chapter 4 -- Cost Function>`
# - {doc}`Chapter 5 -- Gradient Descent 1 </e_extra/pytorch_image_filtering_ml/Chapter 5 -- Gradient Descent 1>`
# - {doc}`Chapter 6 -- Gradient Descent 2 </e_extra/pytorch_image_filtering_ml/Chapter 6 -- Gradient Descent 2>`
# - {doc}`Chapter 7 -- Real (Non-linear) Neural Network </e_extra/pytorch_image_filtering_ml/Chapter 7 -- Real (Non-linear) Neural Network>`
# - {doc}`Chapter 8 -- Feedforward </e_extra/pytorch_image_filtering_ml/Chapter 8 -- Feedforward>`
# - {doc}`Chapter 9 -- Back Propagation </e_extra/pytorch_image_filtering_ml/Chapter 9 -- Back Propagation>`
# - {doc}`Creating custom functions </b_coding/Intro to Python/11_Functions>`
# - {doc}`Creating date-time stamps </b_coding/Pandas/5_time_stamps>`
# - {doc}`Dictionaries </b_coding/Intro to Python/14_Dictionaries>`
# - {doc}`File handling </b_coding/Intro to Python/13_File_handling>`
# - {doc}`Filtering, selecting and assigning </b_coding/Pandas/2_filter_select_assign>`
# - {doc}`Flow control statements </b_coding/Intro to Python/15_Flow_control_statements>`
# - {doc}`For loops </b_coding/Intro to Python/6_For_loops>`
# - {doc}`Handling errors </b_coding/Intro to Python/9_Handling_errors>`
# - {doc}`If statement </b_coding/Intro to Python/3_If_statement>`
# - {doc}`Importing in Python </b_coding/Intro to Python/10_Importing>`
# - {doc}`Introduction </b_coding/Pandas/1_basics>`
# - {doc}`Lambdas </b_coding/Intro to Python/20_Lambdas>`
# - {doc}`Linear regression </c_mathematics/statistics/Linear_Regression>`
# - {doc}`List comprehensions </b_coding/Intro to Python/7_List_comprehensions>`
# - {doc}`Lists </b_coding/Intro to Python/5_Lists>`
# - {doc}`Merging, combining, grouping and sorting </b_coding/Pandas/3_merge_combine_group_sort>`
# - {doc}`Nested lists </b_coding/Intro to Python/8_Nested_lists>`
# - {doc}`NumPy arrays </b_coding/NumPy_Arrays>`
# - {doc}`Plotting </b_coding/Pandas/6_plotting>`
# - {doc}`Plotting data with Matplotlib </b_coding/Intro to Python/17_Matplotlib>`
# - {doc}`Printing and formatting statements </b_coding/Intro to Python/1_Printing_and_formatting_statements>`
# - {doc}`Python classes </b_coding/Intro to Python/19_Classes>`
# - {doc}`Sets </b_coding/Intro to Python/16_Sets>`
# - {doc}`Summary statistics </b_coding/Pandas/4_summary_statistics>`
# - {doc}`Tuples </b_coding/Intro to Python/12_Tuples>`
# - {doc}`Variables </b_coding/Intro to Python/2_Variables>`
# - {doc}`While loops </b_coding/Intro to Python/4_While_loops>`
#
# (module-ginv)=
# ### Geophysical Inversion
#
# [<!-- module-ginv badge --><span class="module module-ginv">Geophysical Inversion</span>](module-ginv)
#
# - {doc}`Eigenvalues and eigenvectors </c_mathematics/linear_algebra/4_Eigenvalues_and_eigenvectors>`
# - {doc}`Linear Algebra in Python </c_mathematics/linear_algebra/5_Linear_Algebra_in_Python>`
# - {doc}`Systems of linear equations </c_mathematics/linear_algebra/2_Linear_Systems>`
# - {doc}`Theory </c_mathematics/linear_algebra/3_Theory>`
#
# (module-gdyn)=
# ### Geodynamics
#
# [<!-- module-gdyn badge --><span class="module module-gdyn">Geodynamics</span>](module-gdyn)
#
# - {doc}`1D Pipe Flow </d_geosciences/Fluid_Dynamics/Lecture5_1D_Pipe_Flow>`
# - {doc}`1D heat conduction (layered medium) </d_geosciences/1D_Heat_Conduction>`
# - {doc}`Navier Stoke Equation </d_geosciences/Fluid_Dynamics/Lecture8_Part1_Navier_Stoke_Equation>`
# - {doc}`Non Linear Viscosity 2D Stokes </d_geosciences/Fluid_Dynamics/Lecture6_Non_Linear_Viscosity_2D_Stokes>`
# - {doc}`Pipe Flow with Heat </d_geosciences/Fluid_Dynamics/Lecture7_Pipe_Flow_with_Heat>`
# - {doc}`SPH Algorithm for Energy Equation </d_geosciences/Fluid_Dynamics/Lecture8_Part2_SPH_Algorithm_For_Energy_Equation>`
#
# (module-gagp)=
# ### Geophysical Analysis Group Project
#
# [<!-- module-gagp badge --><span class="module module-gagp">Geophysical Analysis Group Project</span>](module-gagp)
#
# - {doc}`Common Mid-point Gather </a_modules/seismology/CMP_Common_Mid_Point_Gather>`
# - {doc}`Ghosting </a_modules/seismology/Ghosting>`
# - {doc}`Spatial Aliasing </a_modules/seismology/Spatial_aliasing>`
# - {doc}`Temporal Aliasing </a_modules/seismology/Temporal_aliasing>`
#
# (module-plaphy)=
# ### Planetary Physics
#
# [<!-- module-plaphy badge --><span class="module module-plaphy">Planetary Physics</span>](module-plaphy)
#
# - {doc}`Wave dispersion </d_geosciences/Wave_dispersion>`
