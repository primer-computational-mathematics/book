# %% [markdown]
# # Modules
#
# Here you can find sections created specifically for certain modules, containing notebooks very closely connected to lectures. These are:
#
# ```{tableofcontents}
# ```
#
# Below you can find links to notebooks from the entire website whose content is related to certain modules.

# %% [markdown]
# ## Year 1
# ## Year 2
# ## Year 3/4
